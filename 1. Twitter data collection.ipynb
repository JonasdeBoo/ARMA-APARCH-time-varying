# %% [markdown]
# # 1. Twitter data collection

# %% [markdown]
# This template illustrates the use of `data_collection`. In this template the Twitter data, filtered on tweets containing ESG words are selected.

# %% [markdown]
# ## 1.1. Load relevant data, packages and set user input

# %% [markdown]
# ### 1.1.1. Loading packages

# %% [markdown]
# Load relevant python packages and relevant classes from the python library, containing all classes used for this research.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os, sys

# Load class that returns tweets
sys.path.insert(0, os.path.abspath('C:\\Users\\jdeboo\\PycharmProjects\\TwitterSentimentGARCH2021\\Code\\Data collection'))
from main_api_code import CollectTwitterData

# %% [markdown]
# ### 1.1.2. Load Company identifier data

# %% [markdown]
# Load datafile containing names and Ticker symbols of the 50 largest companies of the S&P500.

# %%
data_loc = r'C:\Users\Jonas\Documents\Data\company_ticker_list_all.xlsx'
df = pd.read_excel(data_loc)

# Quickly leave out Facebook
df = df[df.Symbol != 'FB']

# %% [markdown]
# ### 1.1.3. Create negation filter

# %% [markdown]
# Each company has own negation filter, to satisfy query limits set by Twitter

# %%
df_negation = pd.DataFrame(columns = df['Company'].values)

negation_apple = '(-fruit - eat -\"apple  music\" -\"green apple\" -apple.news -\"apple watch\" -music.apple -apps.apple -\"red apple\" -\"apple juice\" -IOS -\"apple tea\" -\"apple cake\" -\"apple cider\" -playing -games)'
negation_amazon = '(-\"the amazon\" -\"amzn.to\" -\"amazon.com\" -\"brazilian amazon\" -"rainforest" -"https://www.amazon" -"amazon.in" -"https://featurepoints.com" -\"free gift cards\")'
negation_chevron = None
negation_cola = None
negation_exxon = None
#negation_facebook = '(-\"facebook post\" -\"https://www.facebook.com/\" -\"facebook friend\")'
negation_google = '(-\"google play\" -\"google.docs\" -\"google.com\")'
negation_macd = None
negation_microsoft = '(-\"microsoft office\" -\"microsoft teams\")'
negation_netflix = '(-\"watch netflix\" -\"watching netflix\" -\"netflix series\" -\"alteredcarbon\" -\"altered carbon\")'
negation_nike = '(-\"green nike\" -\"nike air\" -\"air max\")'
negation_salesforce = None
negation_tesla = None
negation_walmart = None

negation_row = [negation_apple, negation_amazon, negation_chevron, negation_cola, negation_exxon, 
                negation_google, negation_macd, negation_microsoft, negation_netflix, negation_nike, negation_salesforce,
                negation_tesla, negation_walmart]

df_negation.loc[len(df_negation)] = negation_row

# %% [markdown]
# ### 1.1.4. Set file location

# %% [markdown]
# Set location where to store extracted data

# %%
store_loc = 'C:\\Users\\Jonas\\Documents\\Data\\Tweets\\'

# %% [markdown]
# ### 1.1.5. Set parameters

# %% [markdown]
# Set parameters such as the maximum number of pages, and start date.
#
# *Note*: dates should be included as a string in the format "YYYYMMDDHHmm"

# %%
# Initialize parameters
n_pages = 1000
max_results = 500
start_date = '2011-01-01T00:00:00Z'
critical_date = '2011-01-05T00:00:00Z'
end_date = '2021-08-31T12:00:00Z'

# %% [markdown]
# -----------------------------------------
# -----------------------------------------

# %% [markdown]
# ## 1.2 Get tweets

# %% [markdown]
# Store tweets as a DataFrame in a dictionary where the key matches the normal company name

# %%
# Set counter
counter = 0

# %% [markdown]
# Now find tweets for every company in the company DataFrame `df`. Use per company the company specific negation dictionary

# %%
for i in range(8, len(df)):
    # Set company attributes
    company_name = df.iloc[i]['Company']
    off_comp_name = df.iloc[i]['Official Company Name'] 
    ticker = df.iloc[i]['Symbol']
    
    # Construct attribute to collect tweets
    tweet_obj = CollectTwitterData(n_pages, max_results, start_date, end_date, critical_date, company_name, off_comp_name, ticker, counter, df_negation[company_name][0])
    tweets, counter = tweet_obj.get_tweets()
    
    # unpack public_metrics and discard public_metrics column
    tweets = tweets.reset_index(drop=True)
    tweets[['like_count', 'quote_count', 'reply_count', 'retweet_count']] = pd.DataFrame.from_records(tweets.public_metrics.dropna().tolist())
    tweets.drop(['public_metrics'], axis=1)
        
    file_name = f'tweets {company_name}.csv'   
    tweets.to_csv(store_loc+file_name, header=True)
    print(counter)
# Out:
# 490
# author_id                                                1115588954
# created_at                                 2021-08-24T14:53:38.000Z
# id                                              1430181509563027463
# public_metrics    {'like_count': 0, 'quote_count': 1, 'reply_cou...
# text              am i 25 with a full time job, rent my own hous...
# Name: 489, dtype: object
# 491
# author_id                                                3428657009
# created_at                                 2021-08-19T10:30:33.000Z
# id                                              1428303364622798850
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Three former Netflix employees face charges ov...
# Name: 490, dtype: object
# 493
# author_id                                                 210651550
# created_at                                 2021-08-14T08:06:25.000Z
# id                                              1426455151540375553
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Can consumer streaming habits actually contrib...
# Name: 492, dtype: object
# 493
# author_id                                                 118825734
# created_at                                 2021-08-06T22:52:56.000Z
# id                                              1423779151794688000
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Hey #Netflix why are you accepting $ from unva...
# Name: 492, dtype: object
# 496
# author_id                                       1417818008311926784
# created_at                                 2021-08-01T07:42:44.000Z
# id                                              1421738149122744322
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Netflix for Sale!!!\n(Batch 43) \n\nSHARED ACC...
# Name: 495, dtype: object
# 497
# author_id                                                1467171834
# created_at                                 2021-07-29T05:01:04.000Z
# id                                              1420610304027676673
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Netflix will mandate COVID-19 vaccinations on ...
# Name: 496, dtype: object
# 494
# author_id                                       1382641701840310276
# created_at                                 2021-07-24T06:08:29.000Z
# id                                              1418815328545648987
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              NETFLIX PREMIUM ACCOUNT FOR SALE!\n\n1 MONTH S...
# Name: 493, dtype: object
# 496
# author_id                                       1055227402031370240
# created_at                                 2021-07-18T11:17:50.000Z
# id                                              1416718854701658116
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              The Dead Don't Die on Netflix is such a waste ...
# Name: 495, dtype: object
# 494
# author_id                                       1150157755677859841
# created_at                                 2021-07-11T11:30:27.000Z
# id                                              1414185312704737280
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              VIDEO - Here Are the Three Ingredients to Disr...
# Name: 493, dtype: object
# 498
# author_id                                                2299097479
# created_at                                 2021-07-04T17:38:30.000Z
# id                                              1411741219156283394
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Why waste your energy aggressively critiquing ...
# Name: 497, dtype: object
# 489
# author_id                                                  81761876
# created_at                                 2021-06-28T12:00:09.000Z
# id                                              1409481745758568450
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              📣 Netflix launches merch from their shows!\n\n...
# withheld                                                        NaN
# Name: 488, dtype: object
# 488
# author_id                                        819839041625436162
# created_at                                 2021-06-21T05:36:05.000Z
# id                                              1406848377506058240
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Bored: Binge watch the brand new show @netflix...
# withheld                                                        NaN
# Name: 487, dtype: object
# 498
# author_id                                                   6065452
# created_at                                 2021-06-13T16:18:08.000Z
# id                                              1404110851905183744
# public_metrics    {'like_count': 7, 'quote_count': 0, 'reply_cou...
# text              “It is true, of course, that some might use a ...
# withheld                                                        NaN
# Name: 497, dtype: object
# 496
# author_id                                                3238022908
# created_at                                 2021-06-07T19:52:44.000Z
# id                                              1401990530427404295
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              "Corruption. Betrayal. 200 years of slavery . ...
# withheld                                                        NaN
# Name: 495, dtype: object
# 498
# author_id                                                 422655386
# created_at                                 2021-05-30T21:42:50.000Z
# id                                              1399119132830863360
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Started watching "Money explained" on Netflix,...
# withheld                                                        NaN
# Name: 497, dtype: object
# 498
# author_id                                                4326273257
# created_at                                 2021-05-23T22:32:04.000Z
# id                                              1396594808798466051
# public_metrics    {'like_count': 1, 'quote_count': 0, 'reply_cou...
# text              #ArmyOfTheDead number one on Netflix. @ATT @Di...
# withheld                                                        NaN
# Name: 497, dtype: object
# 495
# author_id                                                2723217086
# created_at                                 2021-05-17T14:50:32.000Z
# id                                              1394304331982295045
# public_metrics    {'like_count': 1, 'quote_count': 0, 'reply_cou...
# text              Creativity is about coming up with the ideas b...
# withheld                                                        NaN
# Name: 494, dtype: object
# 497
# author_id                                                 606822661
# created_at                                 2021-05-11T01:06:44.000Z
# id                                              1391922687803412481
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              #2,298 - N-Plus.\n\nNetflix 2.0 is coming.\n\n...
# withheld                                                        NaN
# Name: 496, dtype: object
# 496
# author_id                                       1207600397839290370
# created_at                                 2021-05-06T17:34:32.000Z
# id                                              1390359337378344961
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              " Are We So Cruel "\nSeason 01 Episode 29\nDes...
# withheld                                                        NaN
# Name: 495, dtype: object
# 500
# author_id                                                   9229732
# created_at                                 2021-05-02T10:15:10.000Z
# id                                              1388799217301397507
# public_metrics    {'like_count': 3, 'quote_count': 0, 'reply_cou...
# text              A federal jury found a former Netflix executiv...
# withheld                                                        NaN
# Name: 499, dtype: object
# 497
# author_id                                        889161056966332420
# created_at                                 2021-04-26T14:48:15.000Z
# id                                              1386693613850083328
# public_metrics    {'like_count': 8, 'quote_count': 0, 'reply_cou...
# text              If you haven’t yet, please watch Life on Our P...
# withheld                                                        NaN
# Name: 496, dtype: object
# 495
# author_id                                                 393760182
# created_at                                 2021-04-21T02:38:28.000Z
# id                                              1384698017513541636
# public_metrics    {'like_count': 12, 'quote_count': 0, 'reply_co...
# text              I’m shocked ppl are shocked by $NFLX sub growt...
# withheld                                                        NaN
# Name: 494, dtype: object
# 496
# author_id                                       1121067340609798144
# created_at                                 2021-04-15T01:40:55.000Z
# id                                              1382509208822816769
# public_metrics    {'like_count': 1, 'quote_count': 0, 'reply_cou...
# text              If you haven’t seen it yet, you should see #Se...
# withheld                                                        NaN
# Name: 495, dtype: object
# 494
# author_id                                        789155302604177408
# created_at                                 2021-04-10T13:53:18.000Z
# id                                              1380881577597661184
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Niente più pesce: drogheria di Hong Kong influ...
# withheld                                                        NaN
# Name: 493, dtype: object
# 497
# author_id                                                 969449616
# created_at                                 2021-04-07T01:30:32.000Z
# id                                              1379607493194682370
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              What Lies Below on Netflix sucks do not waste ...
# withheld                                                        NaN
# Name: 496, dtype: object
# 490
# author_id                                                  21315031
# created_at                                 2021-04-02T16:21:01.000Z
# id                                              1378019650479476737
# public_metrics    {'like_count': 3, 'quote_count': 0, 'reply_cou...
# text              Watch this powerful @netflix documentary with ...
# withheld                                                        NaN
# Name: 489, dtype: object
# 497
# author_id                                                  29590724
# created_at                                 2021-03-30T14:52:15.000Z
# id                                              1376910148216750086
# public_metrics    {'like_count': 2, 'quote_count': 0, 'reply_cou...
# text              Damn #Seaspiracy on Netflix was eye opening AF...
# withheld                                                        NaN
# Name: 496, dtype: object
# 494
# author_id                                                 243117982
# created_at                                 2021-03-27T17:35:18.000Z
# id                                              1375864016258666499
# public_metrics    {'like_count': 17, 'quote_count': 1, 'reply_co...
# text              Impressed that @seaspiracy does such a good jo...
# withheld                                                        NaN
# Name: 493, dtype: object
# 486
# author_id                                       1212780180143362048
# created_at                                 2021-03-24T11:46:27.000Z
# id                                              1374689060388630532
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Seaspiracy examines the global fishing industr...
# withheld                                                        NaN
# Name: 485, dtype: object
# 481
# author_id                                                1950073484
# created_at                                 2021-03-19T14:11:10.000Z
# id                                              1372913542819635210
# public_metrics    {'like_count': 2, 'quote_count': 0, 'reply_cou...
# text              I’m watching Deadly Illusions on Netflix and i...
# withheld                                                        NaN
# Name: 480, dtype: object
# 483
# author_id                                        712365534189375489
# created_at                                 2021-03-15T11:56:31.000Z
# id                                              1371430106011426816
# public_metrics    {'like_count': 1, 'quote_count': 0, 'reply_cou...
# text              We finally know how bad for the environment yo...
# withheld                                                        NaN
# Name: 482, dtype: object
# 492
# author_id                                       1020358298447405056
# created_at                                 2021-03-10T14:36:33.000Z
# id                                              1369658438343659527
# public_metrics    {'like_count': 1, 'quote_count': 0, 'reply_cou...
# text              Great news!! Check out NOW with @davebrownradi...
# withheld                                                        NaN
# Name: 491, dtype: object
# 488
# author_id                                                 405985290
# created_at                                 2021-03-05T10:22:08.000Z
# id                                              1367782471778013188
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              With Disabilities ‘Rarely’ Seen, Netflix Commi...
# withheld                                                        NaN
# Name: 487, dtype: object
# 490
# author_id                                                3264380229
# created_at                                 2021-03-02T11:47:08.000Z
# id                                              1366716701698650114
# public_metrics    {'like_count': 3, 'quote_count': 0, 'reply_cou...
# text              This fierce movie on Netflix is not good o , w...
# withheld                                                        NaN
# Name: 489, dtype: object
# 482
# author_id                                                  20031083
# created_at                                 2021-02-27T18:47:17.000Z
# id                                              1365735273330573318
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Netflix to Invest $100 Million to Improve Dive...
# withheld                                                        NaN
# Name: 481, dtype: object
# 490
# author_id                                                  45230317
# created_at                                 2021-02-25T03:27:27.000Z
# id                                              1364779011088482305
# public_metrics    {'like_count': 2, 'quote_count': 0, 'reply_cou...
# text              Netflix Doc on the Shroud Of Turin, \nreveal t...
# withheld                                                        NaN
# Name: 489, dtype: object
# 478
# author_id                                                4826011694
# created_at                                 2021-02-19T18:55:26.000Z
# id                                              1362838219532865538
# public_metrics    {'like_count': 2, 'quote_count': 0, 'reply_cou...
# text              Who says Netflix binge-watching is a waste of ...
# withheld                                                        NaN
# Name: 477, dtype: object
# 491
# author_id                                                1434147060
# created_at                                 2021-02-14T19:21:35.000Z
# id                                              1361032862070411264
# public_metrics    {'like_count': 8, 'quote_count': 0, 'reply_cou...
# text              Just finished watching @TheMinimalists @netfli...
# Name: 490, dtype: object
# 488
# author_id                                       1170416445861191680
# created_at                                 2021-02-09T05:27:24.000Z
# id                                              1359010992831647745
# public_metrics    {'like_count': 1, 'quote_count': 0, 'reply_cou...
# text              Not even sure why I still pay for @netflix. I’...
# Name: 487, dtype: object
# 471
# author_id                                                 326956063
# created_at                                 2021-02-03T07:16:19.000Z
# id                                              1356864076656312320
# public_metrics    {'like_count': 2, 'quote_count': 0, 'reply_cou...
# text              Netflix has just released the trailer for #MOX...
# Name: 470, dtype: object
# 474
# author_id                                                 257990828
# created_at                                 2021-01-29T05:44:33.000Z
# id                                              1355029043905630210
# public_metrics    {'like_count': 1, 'quote_count': 0, 'reply_cou...
# text              The Netflix Night Stalker series is good, but ...
# Name: 473, dtype: object
# 475
# author_id                                       1311644106091880449
# created_at                                 2021-01-24T11:55:10.000Z
# id                                              1353310370878910465
# public_metrics    {'like_count': 3, 'quote_count': 0, 'reply_cou...
# text              David Attenborough's heartbreaking plea after ...
# Name: 474, dtype: object
# 481
# author_id                                       1300730779295797254
# created_at                                 2021-01-20T22:40:05.000Z
# id                                              1352023116969631750
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Banks don't like Bitcoin.\nTaxis don't like ub...
# Name: 480, dtype: object
# 472
# author_id                                                 407474647
# created_at                                 2021-01-17T02:57:55.000Z
# id                                              1350638453256425475
# public_metrics    {'like_count': 5, 'quote_count': 0, 'reply_cou...
# text              “I really believe that musicians and cooks are...
# Name: 471, dtype: object
# 482
# author_id                                                 194339143
# created_at                                 2021-01-13T18:17:57.000Z
# id                                              1349420435910217728
# public_metrics    {'like_count': 1, 'quote_count': 0, 'reply_cou...
# text              "The neutral period is over. We need the coura...
# Name: 481, dtype: object
# 471
# author_id                                       1332673189172932610
# created_at                                 2021-01-07T08:47:20.000Z
# id                                              1347102506971779077
# public_metrics    {'like_count': 2, 'quote_count': 0, 'reply_cou...
# text              Release from negative feelings Coffee ☕ with t...
# Name: 470, dtype: object
# 479
# author_id                                                 898890936
# created_at                                 2021-01-01T19:02:40.000Z
# id                                              1345083036468195328
# public_metrics    {'like_count': 7, 'quote_count': 0, 'reply_cou...
# text              To anyone who uses my Netflix account just wan...
# Name: 478, dtype: object
# 473
# author_id                                                2251383210
# created_at                                 2020-12-27T14:41:03.000Z
# id                                              1343205257262731273
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Elon Musk said a college degree isn't required...
# Name: 472, dtype: object
# 464
# author_id                                                 213320319
# created_at                                 2020-12-21T03:54:32.000Z
# id                                              1340868227337842696
# public_metrics    {'like_count': 1, 'quote_count': 0, 'reply_cou...
# text              the prom netflix movie will really show you na...
# Name: 463, dtype: object
# 460
# author_id                                                 256210681
# created_at                                 2020-12-15T09:56:08.000Z
# id                                              1338784900196012033
# public_metrics    {'like_count': 2, 'quote_count': 0, 'reply_cou...
# text              ‘Netflix for Toys’ #startup Whirli lands €4.3 ...
# Name: 459, dtype: object
# 457
# author_id                                        824282023002935296
# created_at                                 2020-12-10T01:19:28.000Z
# id                                              1336842936567255043
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Rewatching The West Wing on Netflix before it'...
# Name: 456, dtype: object
# 477
# author_id                                                1524539694
# created_at                                 2020-12-04T19:49:15.000Z
# id                                              1334947897478164481
# public_metrics    {'like_count': 1, 'quote_count': 0, 'reply_cou...
# text              Whatever you do, don't watch "The 2nd" on Netf...
# Name: 476, dtype: object
# 483
# author_id                                                 248991662
# created_at                                 2020-11-29T19:07:01.000Z
# id                                              1333125329301409793
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Perspective | ‘The Queen’s Gambit,’ a period d...
# Name: 482, dtype: object
# 473
# author_id                                       1058924683909890048
# created_at                                 2020-11-24T17:55:35.000Z
# id                                              1331295414881030145
# public_metrics    {'like_count': 15, 'quote_count': 0, 'reply_co...
# text              I hope whoever’s responsible for the skip intr...
# Name: 472, dtype: object
# 483
# author_id                                                2515773062
# created_at                                 2020-11-19T11:06:00.000Z
# id                                              1329380400658079744
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              We all want to fight racism &amp; build a bett...
# Name: 482, dtype: object
# 491
# author_id                                                 103314561
# created_at                                 2020-11-13T16:21:42.000Z
# id                                              1327285520779464705
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Pez Outlaw, "Notes From The Asylum" #Apple #Di...
# Name: 490, dtype: object
# 488
# author_id                                                 321681845
# created_at                                 2020-11-08T11:13:38.000Z
# id                                              1325396053449912323
# public_metrics    {'like_count': 1, 'quote_count': 0, 'reply_cou...
# text              Watching this movie Baby Mamas on Netflix. Why...
# withheld                                                        NaN
# Name: 487, dtype: object
# 492
# author_id                                        835640486278856704
# created_at                                 2020-11-03T05:33:27.000Z
# id                                              1323498506217291777
# public_metrics    {'like_count': 2, 'quote_count': 0, 'reply_cou...
# text              Im watching whose vote counts, explained on ne...
# withheld                                                        NaN
# Name: 491, dtype: object
# 494
# author_id                                                 560710884
# created_at                                 2020-10-28T05:01:12.000Z
# id                                              1321316063196438529
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text                                       Netflix is unhealthy smh
# withheld                                                        NaN
# Name: 493, dtype: object
# 492
# author_id                                       1020116621942145028
# created_at                                 2020-10-22T22:50:00.000Z
# id                                              1319410704600895488
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Have you guys seen the new @AttenboroughSir \n...
# withheld                                                        NaN
# Name: 491, dtype: object
# 488
# author_id                                                  50065957
# created_at                                 2020-10-19T12:01:38.000Z
# id                                              1318160375024594949
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Have you watched "The Social Dilemma" on Netfl...
# withheld                                                        NaN
# Name: 487, dtype: object
# 490
# author_id                                        739213617342631937
# created_at                                 2020-10-14T13:21:40.000Z
# id                                              1316368577281372161
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              https://t.co/xdvQmJwUUv okay why does the cop ...
# withheld                                                        NaN
# Name: 489, dtype: object
# 487
# author_id                                                  14591406
# created_at                                 2020-10-09T20:42:25.000Z
# id                                              1314667558600048641
# public_metrics    {'like_count': 5, 'quote_count': 0, 'reply_cou...
# text              One somewhat unique thing about Netflix (as co...
# withheld                                                        NaN
# Name: 486, dtype: object
# 493
# author_id                                       1165999407956779019
# created_at                                 2020-10-06T12:08:36.000Z
# id                                              1313451088897404928
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              After a month of battling legal case, Netflix ...
# withheld                                                        NaN
# Name: 492, dtype: object
# 494
# author_id                                                  14371689
# created_at                                 2020-10-02T07:00:32.000Z
# id                                              1311924008783355906
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              How Netflix Finds Innovation on the Edge of Ch...
# withheld                                                        NaN
# Name: 493, dtype: object
# 491
# author_id                                       1222679858842456066
# created_at                                 2020-09-28T05:21:30.000Z
# id                                              1310449532417654785
# public_metrics    {'like_count': 2, 'quote_count': 0, 'reply_cou...
# text              If u wanna waste 17 min of ur life go watch wh...
# withheld                                                        NaN
# Name: 490, dtype: object
# 496
# author_id                                        839964697101283328
# created_at                                 2020-09-23T21:01:09.000Z
# id                                              1308874066850447366
# public_metrics    {'like_count': 1, 'quote_count': 0, 'reply_cou...
# text              Entrepreneur Marc Randolph, co-founder and fir...
# withheld                                                        NaN
# Name: 495, dtype: object
# 464
# author_id                                                 272039498
# created_at                                 2020-09-20T18:54:51.000Z
# id                                              1307755115072413697
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Netflix’s Reed Hastings talks about how the wo...
# withheld                                                        NaN
# Name: 463, dtype: object
# 492
# author_id                                                   7624112
# created_at                                 2020-09-16T16:28:01.000Z
# id                                              1306268611846303745
# public_metrics    {'like_count': 4, 'quote_count': 0, 'reply_cou...
# text              The trial of the Chicago Seven, depicted in an...
# Name: 491, dtype: object
# 491
# author_id                                                 100912826
# created_at                                 2020-09-14T12:57:46.000Z
# id                                              1305490928476577794
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              This plot sounds like an episode from a show e...
# Name: 490, dtype: object
# 488
# author_id                                                 294205357
# created_at                                 2020-09-12T16:51:27.000Z
# id                                              1304824957990559745
# public_metrics    {'like_count': 1, 'quote_count': 0, 'reply_cou...
# text              .@GOP @senatemajldr\n\nCovid. Unemployment. Wi...
# Name: 487, dtype: object
# 489
# author_id                                       1194990097298526211
# created_at                                 2020-09-10T19:00:01.000Z
# id                                              1304132538579861504
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              The latest @Netflix documentary "The Social Di...
# Name: 488, dtype: object
# 485
# author_id                                                   5854882
# created_at                                 2020-09-09T04:37:38.000Z
# id                                              1303553124548751365
# public_metrics    {'like_count': 2648, 'quote_count': 272, 'repl...
# text              Our new documentary film #TheSocialDilemma arr...
# Name: 484, dtype: object
# 494
# author_id                                                  34228779
# created_at                                 2020-09-08T02:25:45.000Z
# id                                              1303157545780080642
# public_metrics    {'like_count': 1, 'quote_count': 0, 'reply_cou...
# text              Netflix’s Reed Hastings sees nothing positive ...
# Name: 493, dtype: object
# 491
# author_id                                       1010717836556238848
# created_at                                 2020-09-05T11:41:32.000Z
# id                                              1302210250771181569
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Favoritism exists everywhere, says #Vikramjeet...
# Name: 490, dtype: object
# 487
# author_id                                                2837784071
# created_at                                 2020-08-31T14:24:59.000Z
# id                                              1300439446421221376
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              $spy $gspc $aapl $nflx $goog $tsla Golar LNG J...
# Name: 486, dtype: object
# 494
# author_id                                        977381631940964353
# created_at                                 2020-08-25T03:16:57.000Z
# id                                              1298097002656362496
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              My biggest complaint with the Netflix film Wor...
# Name: 493, dtype: object
# 493
# author_id                                                 386824273
# created_at                                 2020-08-21T00:56:41.000Z
# id                                              1296612150551752706
# public_metrics    {'like_count': 1, 'quote_count': 0, 'reply_cou...
# text              I would've thought a big company like @netflix...
# Name: 492, dtype: object
# 490
# author_id                                                 257145098
# created_at                                 2020-08-17T05:45:53.000Z
# id                                              1295235380472508416
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Finally watched #DavidAyer's #BRIGHT on #Netfl...
# Name: 489, dtype: object
# 493
# author_id                                       1281167095351382022
# created_at                                 2020-08-13T18:45:43.000Z
# id                                              1293982078212747266
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              I bought a itunes gift card THINKING that you ...
# Name: 492, dtype: object
# 491
# author_id                                                  22828899
# created_at                                 2020-08-09T01:40:05.000Z
# id                                              1292274417901412354
# public_metrics    {'like_count': 1, 'quote_count': 0, 'reply_cou...
# text              Loving #Apple TV Even More | I love #Apple TV....
# Name: 490, dtype: object
# 468
# author_id                                       1285187320572981253
# created_at                                 2020-08-04T20:15:00.000Z
# id                                              1290743059026776065
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Surveys are variable, heterosexuals sums appro...
# Name: 467, dtype: object
# 490
# author_id                                                4756930785
# created_at                                 2020-07-30T20:32:01.000Z
# id                                              1288935402536079360
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Netflix is responsible for judgement de-activa...
# Name: 489, dtype: object
# 486
# author_id                                        873622787608457218
# created_at                                 2020-07-25T20:43:01.000Z
# id                                              1287126228324016131
# public_metrics    {'like_count': 17, 'quote_count': 0, 'reply_co...
# text              All of my drug policy pals, mad interesting se...
# Name: 485, dtype: object
# 486
# author_id                                       1265174243664293889
# created_at                                 2020-07-22T04:19:25.000Z
# id                                              1285791533711515654
# public_metrics    {'like_count': 1, 'quote_count': 0, 'reply_cou...
# text              Netflix Shared Account for 75 pesos only (paym...
# Name: 485, dtype: object
# 489
# author_id                                                  25269037
# created_at                                 2020-07-19T06:22:15.000Z
# id                                              1284735282324148224
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              It’s Not Too Late for Hollywood to Change Its ...
# Name: 488, dtype: object
# 489
# author_id                                        822871575636676609
# created_at                                 2020-07-17T20:38:26.000Z
# id                                              1284225973865582592
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              https://t.co/pJHOwAa0XI #zysola #tech #technew...
# Name: 488, dtype: object
# 485
# author_id                                                   8090562
# created_at                                 2020-07-16T16:32:02.000Z
# id                                              1283801577610866689
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              We need to stop waiting for the next Echo or N...
# Name: 484, dtype: object
# 492
# author_id                                       1224780585303969794
# created_at                                 2020-07-12T11:36:00.000Z
# id                                              1282277524979036163
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Netflix's "Unsolved Mysteries" Reboots Mysteri...
# Name: 491, dtype: object
# 493
# author_id                                        804449881720963072
# created_at                                 2020-07-08T01:48:27.000Z
# id                                              1280680113005146112
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              is the new twd season on netflix yet so I can ...
# Name: 492, dtype: object
# 490
# author_id                                       1047363739144470529
# created_at                                 2020-07-03T06:08:25.000Z
# id                                              1278933597848694786
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              I went to watch mamma mia on netflix and it wa...
# Name: 489, dtype: object
# 486
# author_id                                                4536992833
# created_at                                 2020-06-28T09:01:17.000Z
# id                                              1277165160658952192
# public_metrics    {'like_count': 2, 'quote_count': 0, 'reply_cou...
# text              y'all must watch ordinary people on netflix gr...
# Name: 485, dtype: object
# 485
# author_id                                                  15335770
# created_at                                 2020-06-23T06:27:55.000Z
# id                                              1275314623999356929
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              watched Disclosure on Netflix. I do recommend ...
# Name: 484, dtype: object
# 494
# author_id                                                  46124631
# created_at                                 2020-06-18T13:28:26.000Z
# id                                              1273608511021355012
# public_metrics    {'like_count': 4, 'quote_count': 0, 'reply_cou...
# text              The next #LGBTQrights advocate I want to showc...
# Name: 493, dtype: object
# 490
# author_id                                                2966504568
# created_at                                 2020-06-14T06:53:02.000Z
# id                                              1272059457099333633
# public_metrics    {'like_count': 4, 'quote_count': 0, 'reply_cou...
# text              nasira yung netflix moments haha @exoxsbclcdks...
# Name: 489, dtype: object
# 498
# author_id                                                  14548612
# created_at                                 2020-06-10T08:38:48.000Z
# id                                              1270636519993176066
# public_metrics    {'like_count': 6, 'quote_count': 0, 'reply_cou...
# text              Was watching "The Last Days of American Crime"...
# Name: 497, dtype: object
# 494
# author_id                                                 331025405
# created_at                                 2020-06-06T05:42:43.000Z
# id                                              1269142656006971392
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              You know merry men just made it to Netflix. My...
# Name: 493, dtype: object
# 498
# author_id                                                 371283981
# created_at                                 2020-06-02T19:30:09.000Z
# id                                              1267901334101114880
# public_metrics    {'like_count': 8, 'quote_count': 1, 'reply_cou...
# text              Who has watched the space force series on Netf...
# Name: 497, dtype: object
# 495
# author_id                                                 490225792
# created_at                                 2020-05-29T07:54:45.000Z
# id                                              1266276781104852994
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Watched #JeffreyEpsteinFilthyRich on Netflix a...
# Name: 494, dtype: object
# 440
# author_id                                                  75230118
# created_at                                 2020-05-25T13:04:19.000Z
# id                                              1264905133953110016
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              While Netflix hit series Hollywood; looks at h...
# Name: 439, dtype: object
# 430
# author_id                                                 629681184
# created_at                                 2020-05-21T05:19:52.000Z
# id                                              1263338699976323072
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text                                  My netflix list is unhealthy😰
# Name: 429, dtype: object
# 376
# author_id                                                  49913640
# created_at                                 2020-05-16T19:20:39.000Z
# id                                              1261738349338882048
# public_metrics    {'like_count': 2, 'quote_count': 0, 'reply_cou...
# text              All the bastard who recommended ‘kaamyaab’ to ...
# Name: 375, dtype: object
# 431
# author_id                                                 242469235
# created_at                                 2020-05-12T17:29:12.000Z
# id                                              1260260750750253059
# public_metrics    {'like_count': 1, 'quote_count': 0, 'reply_cou...
# text              RT US Stocks are OVERVALUED by 50-75% as COLOS...
# Name: 430, dtype: object
# 329
# author_id                                        924829876636577792
# created_at                                 2020-05-08T21:28:30.000Z
# id                                              1258871423604490244
# public_metrics    {'like_count': 1, 'quote_count': 0, 'reply_cou...
# text              What a complete Joke and monumental waste of m...
# withheld                                                        NaN
# Name: 328, dtype: object
# 0
# 469
# author_id                                                  76574312
# created_at                                 2020-05-04T19:15:53.000Z
# id                                              1257388497570271234
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Such a colossal waste of time and money.\n\nNi...
# Name: 468, dtype: object
# 486
# author_id                                                 173724945
# created_at                                 2020-04-30T22:16:04.000Z
# id                                              1255984288484352000
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Ryan Murphy And Michelle Krusiec On “Being See...
# Name: 485, dtype: object
# 486
# author_id                                                 366533403
# created_at                                 2020-04-27T13:14:01.000Z
# id                                              1254760715056906241
# public_metrics    {'like_count': 2, 'quote_count': 0, 'reply_cou...
# text              STREAM NEVER HAVE I EVER ON NETFLIX. DAMN THIS...
# withheld                                                        NaN
# Name: 485, dtype: object
# 490
# author_id                                                 272785221
# created_at                                 2020-04-23T05:36:20.000Z
# id                                              1253195985238491137
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Y’all really casted Tim riggins as a cult lead...
# withheld                                                        NaN
# Name: 489, dtype: object
# 491
# author_id                                                  22917598
# created_at                                 2020-04-19T16:05:03.000Z
# id                                              1251904652284776449
# public_metrics    {'like_count': 1, 'quote_count': 0, 'reply_cou...
# text              The shift to #remotework has led to some chang...
# withheld                                                        NaN
# Name: 490, dtype: object
# 488
# author_id                                                  15761637
# created_at                                 2020-04-15T20:21:02.000Z
# id                                              1250519522211016705
# public_metrics    {'like_count': 32, 'quote_count': 5, 'reply_co...
# text              Only thing missing from FF/FG policy document ...
# withheld                                                        NaN
# Name: 487, dtype: object
# 473
# author_id                                                   1759181
# created_at                                 2020-04-11T03:27:34.000Z
# id                                              1248814925683834880
# public_metrics    {'like_count': 12, 'quote_count': 1, 'reply_co...
# text              I refuse to watch Tiger King for this very rea...
# withheld                                                        NaN
# Name: 472, dtype: object
# 493
# author_id                                                 299505155
# created_at                                 2020-04-07T19:12:02.000Z
# id                                              1247603056092385281
# public_metrics    {'like_count': 9, 'quote_count': 1, 'reply_cou...
# text              "The series is a carnival sideshow not unlike ...
# withheld                                                        NaN
# Name: 492, dtype: object
# 495
# author_id                                       1072531682341908480
# created_at                                 2020-04-03T06:02:00.000Z
# id                                              1245954684784988161
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              I am NOT the negative thoughts I think\n\n #Fr...
# withheld                                                        NaN
# Name: 494, dtype: object
# 499
# author_id                                                  20927505
# created_at                                 2020-03-30T16:45:56.000Z
# id                                              1244667184221016065
# public_metrics    {'like_count': 1, 'quote_count': 0, 'reply_cou...
# text              The announcement yesterday saw some ppl panic,...
# withheld                                                        NaN
# Name: 498, dtype: object
# 496
# author_id                                                4097939518
# created_at                                 2020-03-26T15:15:26.000Z
# id                                              1243194859965444096
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              How can we overcome the invisible barriers tha...
# withheld                                                        NaN
# Name: 495, dtype: object
# 493
# author_id                                                  48225522
# created_at                                 2020-03-22T19:16:34.000Z
# id                                              1241805989411766272
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Today I watched my 21st Movie on DVD from @net...
# withheld                                                        NaN
# Name: 492, dtype: object
# 495
# author_id                                                3292083452
# created_at                                 2020-03-19T03:13:59.000Z
# id                                              1240476586505166848
# public_metrics    {'like_count': 1, 'quote_count': 0, 'reply_cou...
# text              Should i get netflix now and waste my life wat...
# withheld                                                        NaN
# Name: 494, dtype: object
# 495
# author_id                                                4151159577
# created_at                                 2020-03-14T03:33:28.000Z
# id                                              1238669549974818816
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              If you’re looking for a good way to waste a fe...
# withheld                                                        NaN
# Name: 494, dtype: object
# 491
# author_id                                                 351875321
# created_at                                 2020-03-08T23:26:36.000Z
# id                                              1236795481881264129
# public_metrics    {'like_count': 2, 'quote_count': 0, 'reply_cou...
# text              Fake news! Sad! Carson was totally planning to...
# withheld                                                        NaN
# Name: 490, dtype: object
# 497
# author_id                                       1154747490173771776
# created_at                                 2020-03-02T12:56:15.000Z
# id                                              1234462522914177029
# public_metrics    {'like_count': 0, 'quote_count': 1, 'reply_cou...
# text              NETFLIX ACCOUNT ❗❗❗\n350 FOR 1 MONTH (SOLO)\n1...
# withheld                                                        NaN
# Name: 496, dtype: object
# 497
# ...
# text              Tesla sues ex-director of Google Self-Driving ...
# Name: 495, dtype: object
# 498
# author_id                                                  23152434
# created_at                                 2017-02-01T00:28:02.000Z
# id                                               826587881615585284
# public_metrics    {'like_count': 0, 'quote_count': 1, 'reply_cou...
# text              $V #TreeH:Tesla kills the duck with big batter...
# Name: 497, dtype: object
# 499
# author_id                                                 602890074
# created_at                                 2017-01-29T19:49:46.000Z
# id                                               825793074072788992
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Tesla Employee Stealing Data From Company Comp...
# Name: 498, dtype: object
# 498
# author_id                                                 449292684
# created_at                                 2017-01-27T16:08:59.000Z
# id                                               825012737067536384
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Elon Musk Floated the Idea of a Carbon Tax to ...
# Name: 497, dtype: object
# 495
# author_id                                        713000343945084928
# created_at                                 2017-01-26T22:38:30.000Z
# id                                               824748376025620488
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              https://t.co/OlPLEHxzR0 Elon Musk Floated the ...
# Name: 494, dtype: object
# 500
# author_id                                                2689823029
# created_at                                 2017-01-26T19:27:26.000Z
# id                                               824700291643822087
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              TECH Tesla sues ex-Autopilot director for taki...
# Name: 499, dtype: object
# 497
# author_id                                                  30637573
# created_at                                 2017-01-22T10:00:38.000Z
# id                                               823108101763174401
# public_metrics    {'like_count': 1, 'quote_count': 0, 'reply_cou...
# text              The future of Solar Roof Tiles &amp; the Solar...
# Name: 496, dtype: object
# 499
# author_id                                                1858755415
# created_at                                 2017-01-16T19:55:12.000Z
# id                                               821083401260253184
# public_metrics    {'like_count': 1, 'quote_count': 0, 'reply_cou...
# text              Help fund #documentary #roywdeangrant winner o...
# Name: 498, dtype: object
# 500
# author_id                                        726714759253356544
# created_at                                 2017-01-11T16:12:30.000Z
# id                                               819215417260568576
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Tesla nabs another Apple employee — this time,...
# Name: 499, dtype: object
# 499
# author_id                                                 106815369
# created_at                                 2017-01-07T16:53:30.000Z
# id                                               817776185249820672
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              ..@ElonMusk seems to have @realDonaldTrump's e...
# Name: 498, dtype: object
# 499
# author_id                                                 618080617
# created_at                                 2017-01-05T19:21:05.000Z
# id                                               817088550055198720
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Tesla Flips Switch on Gigafactory to Accelerat...
# Name: 498, dtype: object
# 498
# author_id                                                  30631774
# created_at                                 2016-12-31T14:30:22.000Z
# id                                               815203448736088065
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              The future of Solar Roof Tiles &amp; the Solar...
# Name: 497, dtype: object
# 497
# author_id                                                3905200050
# created_at                                 2016-12-22T17:43:56.000Z
# id                                               811990668390371328
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Tesla, SolarCity, and Ta'u: sun, storage batte...
# Name: 496, dtype: object
# 498
# author_id                                                 385864214
# created_at                                 2016-12-15T09:55:21.000Z
# id                                               809336030952378368
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              It is a pleasure to attend at @AytoLaPalmaCdo ...
# withheld                                                        NaN
# Name: 497, dtype: object
# 496
# author_id                                                 421276200
# created_at                                 2016-12-14T15:34:46.000Z
# id                                               809059063061417984
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              #ElonMusk and #Uber CEO #TravisKalanick are jo...
# withheld                                                        NaN
# Name: 495, dtype: object
# 500
# author_id                                        776183793161940996
# created_at                                 2016-12-05T22:31:05.000Z
# id                                               805902341161435136
# public_metrics    {'like_count': 1, 'quote_count': 0, 'reply_cou...
# text              Tesla Model 3: EV Becomes New Innovation With ...
# withheld                                                        NaN
# Name: 499, dtype: object
# 498
# author_id                                                 166589054
# created_at                                 2016-11-29T09:41:44.000Z
# id                                               803534398092177408
# public_metrics    {'like_count': 1, 'quote_count': 0, 'reply_cou...
# text              Tesla Just Powered a 600-Person Island With Re...
# withheld                                                        NaN
# Name: 497, dtype: object
# 497
# author_id                                        802021515558457344
# created_at                                 2016-11-27T09:54:42.000Z
# id                                               802812887160864768
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Tesla has now over 30,000 employees (25K in US...
# withheld                                                        NaN
# Name: 496, dtype: object
# 494
# author_id                                                  88351974
# created_at                                 2016-11-24T11:31:24.000Z
# id                                               801750060023382017
# public_metrics    {'like_count': 1, 'quote_count': 0, 'reply_cou...
# text              #Solar #Energy • Clean Energy: Tesla to Power ...
# withheld                                                        NaN
# Name: 493, dtype: object
# 493
# author_id                                                 340487547
# created_at                                 2016-11-21T10:30:19.000Z
# id                                               800647523530575873
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Tesla's Musk adds solar roofs to his clean ene...
# withheld                                                        NaN
# Name: 492, dtype: object
# 497
# author_id                                                 453533469
# created_at                                 2016-11-17T22:46:42.000Z
# id                                               799383289303707648
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Tesla-SolarCity clean energy powerhouse gets o...
# withheld                                                        NaN
# Name: 496, dtype: object
# 497
# author_id                                                2872396587
# created_at                                 2016-11-14T16:09:03.000Z
# id                                               798196053774254080
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Trump won't be able to stop the transition to ...
# withheld                                                        NaN
# Name: 496, dtype: object
# 497
# author_id                                                  60193301
# created_at                                 2016-11-11T14:51:29.000Z
# id                                               797089369022730240
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Tesla’s Future in Trump’s World - Elon Musk is...
# withheld                                                        NaN
# Name: 496, dtype: object
# 498
# author_id                                                 599859650
# created_at                                 2016-11-07T23:25:07.000Z
# id                                               795769076257697792
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Tesla's New Solar Roof Is Pretty, But Is It Pr...
# withheld                                                        NaN
# Name: 497, dtype: object
# 497
# author_id                                                2377391612
# created_at                                 2016-11-03T20:30:05.000Z
# id                                               794275479205380104
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Learn how to drive #innovation to the core of ...
# withheld                                                        NaN
# Name: 496, dtype: object
# 500
# author_id                                                3304574767
# created_at                                 2016-11-01T16:52:50.000Z
# id                                               793496031446966272
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Tesla Unveils Fully-Integrated #Solar Roof Sys...
# withheld                                                        NaN
# Name: 499, dtype: object
# 496
# author_id                                                3109870227
# created_at                                 2016-10-31T20:02:04.000Z
# id                                               793181264580837377
# public_metrics    {'like_count': 1, 'quote_count': 0, 'reply_cou...
# text              "Tesla Unveils its New Line of Camouflaged Sol...
# withheld                                                        NaN
# Name: 495, dtype: object
# 499
# author_id                                                 790700036
# created_at                                 2016-10-31T05:48:32.000Z
# id                                               792966466093973504
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              I liked a @YouTube video https://t.co/VwVTRnBW...
# withheld                                                        NaN
# Name: 498, dtype: object
# 497
# author_id                                                  63749872
# created_at                                 2016-10-29T20:25:19.000Z
# id                                               792462339140415490
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              I love the innovation from Tesla #Tesla Tesla’...
# withheld                                                        NaN
# Name: 496, dtype: object
# 498
# author_id                                                  48283061
# created_at                                 2016-10-29T11:57:27.000Z
# id                                               792334530606669825
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Tesla's Musk adds solar roofs to his clean ene...
# withheld                                                        NaN
# Name: 497, dtype: object
# 500
# author_id                                                 128288109
# created_at                                 2016-10-29T04:10:38.000Z
# id                                               792217049988673536
# public_metrics    {'like_count': 3, 'quote_count': 0, 'reply_cou...
# text              Elon Musk unveils solar roofs, showcasing his ...
# withheld                                                        NaN
# Name: 499, dtype: object
# 499
# author_id                                                2938891342
# created_at                                 2016-10-29T02:38:37.000Z
# id                                               792193895257956353
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              #Marijuana #WEED UPDATE 1-Tesla's Musk adds so...
# withheld                                                        NaN
# Name: 498, dtype: object
# 498
# author_id                                        763543630011174914
# created_at                                 2016-10-26T21:36:57.000Z
# id                                               791393203291381760
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Tesla reveals more details about its plan to c...
# withheld                                                        NaN
# Name: 497, dtype: object
# 496
# author_id                                        783820411871961088
# created_at                                 2016-10-20T16:48:37.000Z
# id                                               789146313170366464
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Tesla teaches there employees to educate, not ...
# withheld                                                        NaN
# Name: 495, dtype: object
# 497
# author_id                                                  35821850
# created_at                                 2016-10-15T07:07:50.000Z
# id                                               787188214217871360
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              Murray vs. Musk: Coal CEO Calls Tesla a “Fraud...
# withheld                                                        NaN
# Name: 496, dtype: object
# 495
# author_id                                                  48794284
# created_at                                 2016-10-11T22:55:36.000Z
# id                                               785977176185155584
# public_metrics    {'like_count': 0, 'quote_count': 0, 'reply_cou...
# text              JB Straubel, Tesla CTO, Presents Keynote To Ho...
# withheld                                                        NaN
# Name: 494, dtype: object
# Error, sleep for 15 seconds, error is {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-a6cd59af4e1d> in <module>
#       7     # Construct attribute to collect tweets
#       8     tweet_obj = CollectTwitterData(n_pages, max_results, start_date, end_date, critical_date, company_name, off_comp_name, ticker, counter, df_negation[company_name][0])
# ----> 9     tweets, counter = tweet_obj.get_tweets()
#      10
#      11     # unpack public_metrics and discard public_metrics column
#
# ~\PycharmProjects\TwitterSentimentGARCH2021\Code\Data collection\main_api_code.py in get_tweets(self)
#     155
#     156         while tweets.iloc[-1].created_at > self.critical_date:
# --> 157             new_tweets, counter = self.find_tweets(tweets.iloc[-1].created_at, counter)
#     158
#     159             tweets = tweets.append(new_tweets)
#
# ~\PycharmProjects\TwitterSentimentGARCH2021\Code\Data collection\main_api_code.py in find_tweets(self, end_date, counter)
#     131                 continue
#     132
# --> 133             print(data_dict['meta']['result_count'])
#     134
#     135             if data_dict['meta']['result_count'] != 0:
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# -------------------------------------------
# -------------------------------------------
